# %%
import pandas as pd
import requests
import re
import os 
import sys
import json
import csv

# %%
#视频AV号列表 
aid_list=[]
#评论用户极其信息
info_list=[]

# %%
#获取指定UP的所有视频的AV号 mid:用户编号 size:单次拉取数目 page:页数
def getAllAVList(mid,size,page):
    #获取up主视频列表
    for n in range(1,page+1):
        url="http://space.bilibili.com/ajax/member/getSubmitVideos?mid="+\
            str(mid)+"&pagesize="+str(size)+"&page="+str(n)
        r=requests.get(url)
        text=r.text
        json_text=json.loads(text)
#        print(json_text)
        for item in json_text["data"]["vlist"]:
            aid_list.append(item["aid"])
    print(aid_list)

# %%
#获取一个AV号视频下所有评论
def getAllCommentList(item):
    url="http://api.bilibili.com/x/reply?type=1&oid=" + str(item) + "&pn=1&nohot=1&sort=0"
    r=requests.get(url)
    numtext=r.text
    json_text=json.loads(numtext)
#     print(json_text)
    commentsNum=json_text['data']["page"]["count"]
    page=commentsNum//20+1
    for n in range(1,page):
        url="https://api.bilibili.com/x/v2/reply?jsonp&pn"+str(n)+"&type=1&oid="+str(item)+"&sort=1&nohot=1"
        req=requests.get(url)
        text=req.text
        json_text_list=json.loads(text)
        for i in json_text_list['data']["replies"]:
            info_list.append([i["member"]["uname"],i['member']['sex'],i["content"]["message"]])

# %%
def saveTxt(item,filecontent):
    comments=pd.DataFrame(columns=['item','name','sex','comment'])
    for content in filecontent:
        t=pd.DataFrame([[item,content[0],content[1],content[2]]],columns=['item','name','sex','comment'])
        comments=pd.concat([comments,t])
    comments.to_csv(str(item)+".csv",)
    print("文件写入中")

# %%
if __name__=="__main__":
    getAllAVList(31653614,5,8)
    all_comments=pd.DataFrame(columns=['item','name','sex','comment'])
    for item in aid_list:
        info_list.clear()
        getAllCommentList(item)
        saveTxt(item,info_list)
        a=pd.read_csv(str(item)+".csv")
        all_comments=pd.concat([all_comments,a])
    all_comments.to_csv("all_comments.csv")
# Out:
# [47554412, 47481432, 46969538, 46522007, 46440169, 46142444, 45999834, 45599202, 45244225, 44962844, 44486674, 44286331, 43868644, 43335017, 42067671, 41923904, 41752003, 41599163, 39825113, 39627012, 39118390, 38759745, 38759108, 38218289, 38005644, 37872320, 37790041, 37630156, 37330946, 36811260, 36647550, 36314852, 35483211, 35483087, 35482931, 35482826, 35482645, 35482535, 35482310, 35482156, 47554412, 47481432, 46969538, 46522007, 46440169, 46142444, 45999834, 45599202, 45244225, 44962844, 44486674, 44286331, 43868644, 43335017, 42067671, 41923904, 41752003, 41599163, 39825113, 39627012, 39118390, 38759745, 38759108, 38218289, 38005644, 37872320, 37790041, 37630156, 37330946, 36811260, 36647550, 36314852, 35483211, 35483087, 35482931, 35482826, 35482645, 35482535, 35482310, 35482156]
# 文件写入中
# 文件写入中
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   if __name__ == '__main__':
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入中
# 文件写入
# 7          0.0                                           不会打嘟噜怎么办  35482310
# 8          0.0                                             好可爱啊~~  35482310
# 9          0.0                                              不会打嘟噜  35482310
# 10         0.0                                              可以学到了  35482310
# 11         0.0                               老师把额头遮一些会好看很多[小电视_笑]  35482310
# 12         0.0                                             怎么变漂亮了  35482310
# 13         0.0                                  56秒开嗓 okok(=・ω・=)  35482310
# 14         0.0                                         老师，你有男朋友吗？  35482310
# 15         0.0                                                记住啦  35482310
# 16         0.0                                             老师好漂亮！  35482310
# 17         0.0                                                好可爱  35482310
# 18         0.0                                              前排打卡！  35482310
# 19         0.0                                              (･∀･)  35482310
#
#              name sex
# 0        谈笑风生又一年啊   男
# 1        2019_Leo  保密
# 2          2到正无穷。  保密
# 3            简尔不寒   女
# 4          范迪塞尔__   男
# 5            我还是猪  保密
# 6           贝娜和小京  保密
# 7            天使铃兰  保密
# 8           小泉萌香p  保密
# 9        热心小市民qwq  保密
# 10       ミ夏沐ヽsama  保密
# 11      Mila呀Mila  保密
# 12            曾士帥  保密
# 13        许许许许许良人  保密
# 14      春夏的名字字数不够  保密
# 15          小小的玉立   女
# 16    Nutcracker丶  保密
# 17        大王喊我来答题  保密
# 18        爱吃蔬菜的大喵  保密
# 19            枫玘_  保密
# 0        谈笑风生又一年啊   男
# 1           耿直的强儿   男
# 2          打工的小伙子  保密
# 3           萌伢小奇奇  保密
# 4         是YUN繁芸呐  保密
# 5        shauny格瑞  保密
# 6              扫花  保密
# 7          yivain  保密
# 8             z賍斕   女
# 9           灵魂改造者   男
# ..            ...  ..
# 10           瓜皮得很  保密
# 11            罹球球  保密
# 12            漪晴晴   女
# 13           鹏同学_  保密
# 14            井鱼y   男
# 15        AysoQAQ  保密
# 16         发送弹幕失败   男
# 17         与番茄君共眠  保密
# 18           古树生青  保密
# 19           _睡不醒  保密
# 0            离人未殇   女
# 1             弎角猫  保密
# 2          七刀七刀七刀  保密
# 3            真讨厌啊   女
# 4           专属式KR   男
# 5          吃甜了了了丶   女
# 6   站长大人biubiubiu   男
# 7           SelaK   女
# 8            京_Qi   女
# 9           纱雾__酱  保密
# 10          糖醋小畜生  保密
# 11        dickyee  保密
# 12          星奈ちゃん   男
# 13         DKPKPK   男
# 14           博山博士   男
# 15           麀鹿子哟   女
# 16        废铁直男王没钱   男
# 17           木白ao   女
# 18          昂水小朋友   男
# 19           小糖尼克   男
#
# [1760 rows x 5 columns]

# %%
for item in aid_list:
    data = pd.read_csv(str(item)+'.csv',encoding='utf8',engine='python')
    episode_comment_dic[i] = sum(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-7ce1dbeff214> in <module>
# ----> 1 data = pd.read_csv(path.strip(),encoding='utf8',engine='python')
#
# NameError: name 'path' is not defined

# %%
def every_episode_comment_change(episode_comment_dic)：
    line=pyecharts.Line("每集弹幕变化总量")，"2019-4-1",width=1200,height=600)
    keys=[]
    values=[]
    for i in episode_comment_dic:
        keys.append("第")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-e28c1f334648> in <module>
# ----> 1 episode_comment_dic[i] = sum(all_comments)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
